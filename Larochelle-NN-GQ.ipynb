# %%
from module_imports import *
from download_data import *
from import_data import *
from larochelle_nn import *

# %matplotlib inline


#download_quandl()
#download_goog()
#'''
#Q_stock_df, Q_prediction_df, Q_pred_tickers = get_quandl_data()
#G_stock_df, G_prediction_df, G_pred_tickers = get_goog_data()

#GQ_df = pd.merge(Q_stock_df, G_stock_df, how='outer', on=['ticker', 'date']).dropna()
#GQ_df = GQ_df[GQ_df['label_x'] == GQ_df['label_y']]

#GQ_prediction_df = pd.merge(Q_prediction_df, G_prediction_df, how='outer', on=['ticker', 'date'])

#GQ_df.to_csv('GQ_df.csv', index=False)
#GQ_prediction_df.to_csv('GQ_prediction_df.csv', index=False)
#'''
GQ_df = pd.read_csv('GQ_df.csv')
GQ_prediction_df = pd.read_csv('GQ_prediction_df.csv')

# %%
GQ_df['ticker'].value_counts()[:10]
# Out:
# SGYP    48
# BABY    48
# SGMO    48
# THLD    48
# SGEN    48
# ACOR    48
# RPRX    48
# NSTG    48
# AFFX    48
# BCRX    48
# dtype: int64

# %%
tickers_to_save = []
for ticker in GQ_df['ticker'].unique():
    ticker_df = GQ_df[GQ_df['ticker'] == ticker]
    if (ticker_df['label_x'] >= 0.03).value_counts().index[0]:
        tickers_to_save.append(ticker)
    else:
        GQ_df = GQ_df[GQ_df['ticker'] != ticker]

# %%
print [x for x in tickers_to_save]
# Out:
# ['ABIO', 'ACOR', 'AERI', 'AFFX', 'AGEN', 'ARIA', 'ARNA', 'ARWR', 'AXDX', 'BCLI', 'BCRX', 'BLUE', 'CBMG', 'CBPO', 'CGEN', 'CLDN', 'CLDX', 'CPRX', 'CRIS', 'CYNO', 'CYTR', 'DSCO', 'DYAX', 'ECYT', 'ENZN', 'EXAS', 'EXEL', 'FATE', 'FLDM', 'GNCA', 'HALO', 'HSKA', 'IDRA', 'IMMU', 'INCY', 'INO', 'LJPC', 'LPCN', 'LPTN', 'MEIP', 'MNKD', 'MNTA', 'MYGN', 'NBIX', 'NSTG', 'NVAX', 'NVDQ', 'OGXI', 'ONTY', 'OREX', 'OSIR', 'OXGN', 'PACB', 'PGNX', 'PHMD', 'PSTI', 'QLTI', 'RGEN', 'RMTI', 'RPRX', 'SGEN', 'SGMO', 'SGYP', 'SNMX', 'SPNC', 'SRNE', 'SSH', 'STEM', 'SURG', 'THLD', 'TNXP', 'TROV', 'TRVN', 'VICL', 'XLRN', 'ZLTQ']

# %%
GQ_df[GQ_df['label_x'] >= 0.05].shape
# Out:
# (1643, 98)

# %%
GQ_df[GQ_df['label_x'] < 0.05].shape
# Out:
# (1566, 98)

# %% [markdown]
# ---

# %%
binarize = [True]
gt = [0, 1.0, 2.0]
lt = [5.0, 10.0, 20.0, 50.0, 100.0]
vol = [0, 100, 1000]

balance_labeled_data = [False]
vectorize_label = True

k = 'random'
h = 'random'

epochs = 200
Lambda = [0.0001, 0.001, 0.01, 0.1, 1.0]
Reg = ['L2', 'L1']
alpha = [0.0001, 0.001, 0.01, 0.1]

# RANDOM SEARCH
for i in xrange(20):
    NN_SGD(GQ_df, np.random.choice(binarize), np.random.choice(gt), np.random.choice(lt), np.random.choice(vol), np.random.choice(balance_labeled_data), vectorize_label, k, h, h, epochs, np.random.choice(Lambda), np.random.choice(Reg), np.random.choice(alpha), plot=True)
# Out:
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 0.001
# last mean validation loss: 0.67
# last mean training loss: 0.66
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 1.44692874144e-30
# last mean validation loss: 0.66
# last mean training loss: 0.64
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 1.01044382841e-61
# last mean validation loss: 0.65
# last mean training loss: 0.63
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 9.83095960471e-96
# last mean validation loss: 0.65
# last mean training loss: 0.63
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 6.89878943699e-132
# last mean validation loss: 0.65
# last mean training loss: 0.62
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 9.32280987154e-170
# last mean validation loss: 0.65
# last mean training loss: 0.63
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 4.66787965517e-209
# last mean validation loss: 0.65
# last mean training loss: 0.63
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 1.38240046284e-249
# last mean validation loss: 0.65
# last mean training loss: 0.63
# h1: 21 h2: 21 epochs: 200 Lambda: 0.01 Reg: L2 alpha: 3.44034572162e-291
# last mean validation loss: 0.65
# last mean training loss: 0.63
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 0.0001
# last mean validation loss: 0.66
# last mean training loss: 0.68
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.44692874144e-31
# last mean validation loss: 0.67
# last mean training loss: 0.66
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.01044382841e-62
# last mean validation loss: 0.67
# last mean training loss: 0.65
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.83095960471e-97
# last mean validation loss: 0.68
# last mean training loss: 0.64
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 6.89878943699e-133
# last mean validation loss: 0.68
# last mean training loss: 0.63
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.32280987154e-171
# last mean validation loss: 0.68
# last mean training loss: 0.63
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 4.66787965517e-210
# last mean validation loss: 0.68
# last mean training loss: 0.63
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.38240046284e-250
# last mean validation loss: 0.68
# last mean training loss: 0.62
# h1: 28 h2: 28 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 3.44034572162e-292
# last mean validation loss: 0.68
# last mean training loss: 0.62
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 0.0001
# last mean validation loss: 0.85
# last mean training loss: 0.71
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 1.44692874144e-31
# last mean validation loss: 0.83
# last mean training loss: 0.67
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 1.01044382841e-62
# last mean validation loss: 0.82
# last mean training loss: 0.66
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 9.83095960471e-97
# last mean validation loss: 0.82
# last mean training loss: 0.65
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 6.89878943699e-133
# last mean validation loss: 0.81
# last mean training loss: 0.65
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 9.32280987154e-171
# last mean validation loss: 0.81
# last mean training loss: 0.64
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 4.66787965517e-210
# last mean validation loss: 0.81
# last mean training loss: 0.64
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 1.38240046284e-250
# last mean validation loss: 0.81
# last mean training loss: 0.64
# h1: 5 h2: 5 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 3.44034572162e-292
# last mean validation loss: 0.81
# last mean training loss: 0.64
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 0.0001
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 1.44692874144e-31
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 1.01044382841e-62
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 9.83095960471e-97
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 6.89878943699e-133
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 9.32280987154e-171
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 4.66787965517e-210
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 1.38240046284e-250
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 77 h2: 77 epochs: 200 Lambda: 1.0 Reg: L1 alpha: 3.44034572162e-292
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 0.01
# last mean validation loss: 0.69
# last mean training loss: 0.71
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 1.44692874144e-29
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 1.01044382841e-60
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 9.83095960471e-95
# last mean validation loss: 0.7
# last mean training loss: 0.7
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 6.89878943699e-131
# last mean validation loss: 0.7
# last mean training loss: 0.7
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 9.32280987154e-169
# last mean validation loss: 0.7
# last mean training loss: 0.7
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 4.66787965517e-208
# last mean validation loss: 0.7
# last mean training loss: 0.7
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 1.38240046284e-248
# last mean validation loss: 0.7
# last mean training loss: 0.7
# h1: 19 h2: 19 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 3.44034572162e-290
# last mean validation loss: 0.7
# last mean training loss: 0.7
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 0.0001
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.44692874144e-31
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.01044382841e-62
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 9.83095960471e-97
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 6.89878943699e-133
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 9.32280987154e-171
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 4.66787965517e-210
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.38240046284e-250
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 78 h2: 78 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 3.44034572162e-292
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 0.001
# last mean validation loss: 0.64
# last mean training loss: 0.65
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.44692874144e-30
# last mean validation loss: 0.63
# last mean training loss: 0.63
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.01044382841e-61
# last mean validation loss: 0.63
# last mean training loss: 0.62
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.83095960471e-96
# last mean validation loss: 0.63
# last mean training loss: 0.61
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 6.89878943699e-132
# last mean validation loss: 0.63
# last mean training loss: 0.61
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.32280987154e-170
# last mean validation loss: 0.63
# last mean training loss: 0.6
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 4.66787965517e-209
# last mean validation loss: 0.63
# last mean training loss: 0.6
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.38240046284e-249
# last mean validation loss: 0.63
# last mean training loss: 0.6
# h1: 10 h2: 10 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 3.44034572162e-291
# last mean validation loss: 0.63
# last mean training loss: 0.6
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 0.01
# last mean validation loss: 0.65
# last mean training loss: 0.59
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 1.44692874144e-29
# last mean validation loss: 0.68
# last mean training loss: 0.53
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 1.01044382841e-60
# last mean validation loss: 0.69
# last mean training loss: 0.5
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 9.83095960471e-95
# last mean validation loss: 0.69
# last mean training loss: 0.49
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 6.89878943699e-131
# last mean validation loss: 0.69
# last mean training loss: 0.5
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 9.32280987154e-169
# last mean validation loss: 0.69
# last mean training loss: 0.5
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 4.66787965517e-208
# last mean validation loss: 0.7
# last mean training loss: 0.5
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 1.38240046284e-248
# last mean validation loss: 0.7
# last mean training loss: 0.5
# h1: 60 h2: 60 epochs: 200 Lambda: 0.001 Reg: L2 alpha: 3.44034572162e-290
# last mean validation loss: 0.7
# last mean training loss: 0.51
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 0.01
# last mean validation loss: 0.7
# last mean training loss: 0.75
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.44692874144e-29
# last mean validation loss: 0.69
# last mean training loss: 0.72
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.01044382841e-60
# last mean validation loss: 0.69
# last mean training loss: 0.71
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 9.83095960471e-95
# last mean validation loss: 0.69
# last mean training loss: 0.71
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 6.89878943699e-131
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 9.32280987154e-169
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 4.66787965517e-208
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.38240046284e-248
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 84 h2: 84 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 3.44034572162e-290
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 0.01
# last mean validation loss: 0.69
# last mean training loss: 0.72
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 1.44692874144e-29
# last mean validation loss: 0.69
# last mean training loss: 0.71
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 1.01044382841e-60
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 9.83095960471e-95
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 6.89878943699e-131
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 9.32280987154e-169
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 4.66787965517e-208
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 1.38240046284e-248
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 28 h2: 28 epochs: 200 Lambda: 0.1 Reg: L1 alpha: 3.44034572162e-290
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 0.0001
# last mean validation loss: 0.72
# last mean training loss: 0.7
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 1.44692874144e-31
# last mean validation loss: 0.7
# last mean training loss: 0.69
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 1.01044382841e-62
# last mean validation loss: 0.7
# last mean training loss: 0.68
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 9.83095960471e-97
# last mean validation loss: 0.69
# last mean training loss: 0.68
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 6.89878943699e-133
# last mean validation loss: 0.69
# last mean training loss: 0.68
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 9.32280987154e-171
# last mean validation loss: 0.69
# last mean training loss: 0.68
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 4.66787965517e-210
# last mean validation loss: 0.69
# last mean training loss: 0.68
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 1.38240046284e-250
# last mean validation loss: 0.69
# last mean training loss: 0.68
# h1: 9 h2: 9 epochs: 200 Lambda: 0.01 Reg: L1 alpha: 3.44034572162e-292
# last mean validation loss: 0.69
# last mean training loss: 0.68
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 0.01
# last mean validation loss: 0.69
# last mean training loss: 0.74
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 1.44692874144e-29
# last mean validation loss: 0.69
# last mean training loss: 0.72
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 1.01044382841e-60
# last mean validation loss: 0.69
# last mean training loss: 0.71
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 9.83095960471e-95
# last mean validation loss: 0.69
# last mean training loss: 0.71
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 6.89878943699e-131
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 9.32280987154e-169
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 4.66787965517e-208
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 1.38240046284e-248
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 62 h2: 62 epochs: 200 Lambda: 0.1 Reg: L2 alpha: 3.44034572162e-290
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 0.0001
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.44692874144e-31
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.01044382841e-62
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 9.83095960471e-97
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 6.89878943699e-133
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 9.32280987154e-171
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 4.66787965517e-210
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.38240046284e-250
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 14 h2: 14 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 3.44034572162e-292
# last mean validation loss: 0.69
# last mean training loss: 0.69
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 0.1
# last mean validation loss: 0.88
# last mean training loss: 0.41
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.44692874144e-28
# last mean validation loss: 1.11
# last mean training loss: 0.25
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.01044382841e-59
# last mean validation loss: 1.19
# last mean training loss: 0.18
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.83095960471e-94
# last mean validation loss: 1.23
# last mean training loss: 0.15
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 6.89878943699e-130
# last mean validation loss: 1.25
# last mean training loss: 0.13
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.32280987154e-168
# last mean validation loss: 1.27
# last mean training loss: 0.12
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 4.66787965517e-207
# last mean validation loss: 1.28
# last mean training loss: 0.12
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.38240046284e-247
# last mean validation loss: 1.29
# last mean training loss: 0.12
# h1: 48 h2: 48 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 3.44034572162e-289
# last mean validation loss: 1.3
# last mean training loss: 0.12
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 0.1
# last mean validation loss: 0.69
# last mean training loss: 0.74
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.44692874144e-28
# last mean validation loss: 0.69
# last mean training loss: 0.71
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.01044382841e-59
# last mean validation loss: 0.69
# last mean training loss: 0.71
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 9.83095960471e-94
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 6.89878943699e-130
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 9.32280987154e-168
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 4.66787965517e-207
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 1.38240046284e-247
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 12 h2: 12 epochs: 200 Lambda: 1.0 Reg: L2 alpha: 3.44034572162e-289
# last mean validation loss: 0.69
# last mean training loss: 0.7
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 0.01
# last mean validation loss: 0.66
# last mean training loss: 0.56
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 1.44692874144e-29
# last mean validation loss: 0.69
# last mean training loss: 0.48
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 1.01044382841e-60
# last mean validation loss: 0.7
# last mean training loss: 0.45
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 9.83095960471e-95
# last mean validation loss: 0.7
# last mean training loss: 0.43
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 6.89878943699e-131
# last mean validation loss: 0.7
# last mean training loss: 0.41
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 9.32280987154e-169
# last mean validation loss: 0.71
# last mean training loss: 0.41
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 4.66787965517e-208
# last mean validation loss: 0.71
# last mean training loss: 0.4
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 1.38240046284e-248
# last mean validation loss: 0.71
# last mean training loss: 0.39
# h1: 58 h2: 58 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 3.44034572162e-290
# last mean validation loss: 0.71
# last mean training loss: 0.39
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 0.01
# last mean validation loss: 0.64
# last mean training loss: 0.53
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.44692874144e-29
# last mean validation loss: 0.7
# last mean training loss: 0.44
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.01044382841e-60
# last mean validation loss: 0.72
# last mean training loss: 0.42
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.83095960471e-95
# last mean validation loss: 0.73
# last mean training loss: 0.42
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 6.89878943699e-131
# last mean validation loss: 0.74
# last mean training loss: 0.41
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.32280987154e-169
# last mean validation loss: 0.74
# last mean training loss: 0.4
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 4.66787965517e-208
# last mean validation loss: 0.75
# last mean training loss: 0.39
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.38240046284e-248
# last mean validation loss: 0.75
# last mean training loss: 0.38
# h1: 23 h2: 23 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 3.44034572162e-290
# last mean validation loss: 0.75
# last mean training loss: 0.37
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 0.0001
# last mean validation loss: 0.72
# last mean training loss: 0.71
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.44692874144e-31
# last mean validation loss: 0.71
# last mean training loss: 0.7
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.01044382841e-62
# last mean validation loss: 0.7
# last mean training loss: 0.69
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.83095960471e-97
# last mean validation loss: 0.7
# last mean training loss: 0.69
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 6.89878943699e-133
# last mean validation loss: 0.7
# last mean training loss: 0.69
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 9.32280987154e-171
# last mean validation loss: 0.7
# last mean training loss: 0.69
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 4.66787965517e-210
# last mean validation loss: 0.7
# last mean training loss: 0.69
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 1.38240046284e-250
# last mean validation loss: 0.7
# last mean training loss: 0.69
# h1: 31 h2: 31 epochs: 200 Lambda: 0.0001 Reg: L2 alpha: 3.44034572162e-292
# last mean validation loss: 0.7
# last mean training loss: 0.69
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 0.01
# last mean validation loss: 0.62
# last mean training loss: 0.62
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 1.44692874144e-29
# last mean validation loss: 0.62
# last mean training loss: 0.55
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 1.01044382841e-60
# last mean validation loss: 0.62
# last mean training loss: 0.53
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 9.83095960471e-95
# last mean validation loss: 0.62
# last mean training loss: 0.53
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 6.89878943699e-131
# last mean validation loss: 0.62
# last mean training loss: 0.52
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 9.32280987154e-169
# last mean validation loss: 0.62
# last mean training loss: 0.52
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 4.66787965517e-208
# last mean validation loss: 0.62
# last mean training loss: 0.52
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 1.38240046284e-248
# last mean validation loss: 0.62
# last mean training loss: 0.52
# h1: 48 h2: 48 epochs: 200 Lambda: 0.001 Reg: L1 alpha: 3.44034572162e-290
# last mean validation loss: 0.62
# last mean training loss: 0.52
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 0.001
# last mean validation loss: 0.63
# last mean training loss: 0.63
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 1.44692874144e-30
# last mean validation loss: 0.62
# last mean training loss: 0.62
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 1.01044382841e-61
# last mean validation loss: 0.61
# last mean training loss: 0.61
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 9.83095960471e-96
# last mean validation loss: 0.61
# last mean training loss: 0.6
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 6.89878943699e-132
# last mean validation loss: 0.61
# last mean training loss: 0.59
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 9.32280987154e-170
# last mean validation loss: 0.61
# last mean training loss: 0.58
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 4.66787965517e-209
# last mean validation loss: 0.61
# last mean training loss: 0.57
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 1.38240046284e-249
# last mean validation loss: 0.61
# last mean training loss: 0.56
# h1: 14 h2: 14 epochs: 200 Lambda: 0.0001 Reg: L1 alpha: 3.44034572162e-291
# last mean validation loss: 0.61
# last mean training loss: 0.56

# %% [markdown]
# ---

# %%
binarize = True
gt = 0.0
lt = 50.0
vol = 0

balance_labeled_data = False
vectorize_label = True

k = 30
h = 5

epochs = 500
Lambda = 0.001
Reg = 'L2'
alpha = 0.001

W,b,X_test,y_test,skb,scaler = NN_SGD(GQ_df, binarize, gt, lt, vol, balance_labeled_data, vectorize_label, k, h, h, epochs, Lambda, Reg, alpha, plot=True)
# Out:
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.001
# last mean validation loss: 0.63
# last mean training loss: 0.6
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 1.44692874144e-30
# last mean validation loss: 0.61
# last mean training loss: 0.53
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 1.01044382841e-61
# last mean validation loss: 0.6
# last mean training loss: 0.48
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 9.83095960471e-96
# last mean validation loss: 0.59
# last mean training loss: 0.45
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 6.89878943699e-132
# last mean validation loss: 0.59
# last mean training loss: 0.44
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 9.32280987154e-170
# last mean validation loss: 0.59
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 4.66787965517e-209
# last mean validation loss: 0.59
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 1.38240046284e-249
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 3.44034572162e-291
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.44
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.44
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.44
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43
# h1: 5 h2: 5 epochs: 500 Lambda: 0.001 Reg: L2 alpha: 0.0
# last mean validation loss: 0.58
# last mean training loss: 0.43

# %% [markdown]
# ---

# %%
def loss(f_x,y):
    if y.shape[0] > 1:
        i = np.where(y == 1)[0][0]
        return -np.log(f_x[i]) # negative log-likelihood
    else:
        return -np.log(f_x)
#print f_x, y
#print
#print -np.log(f_x)
#print
#return -np.log(f_x)
#print f_x[1], y[1]
#return -np.log(f_x[1])

def forward_prop(x, W1, b1, W2, b2, W3, b3):
    def sigm(z):
        return 1/(1+np.exp(-z))
    
    def tanh(z):
        return (np.exp(2*z)-1)/(np.exp(2*z)+1)

    def softmax(z):
        return np.exp(z)/np.sum(np.exp(z))

    z1 = b1 + np.dot(W1,x)
    a1 = sigm(z1)

    z2 = b2 + np.dot(W2,a1)
    a2 = sigm(z2)

    z3 = b3 + np.dot(W3,a2)
    a3 = softmax(z3)

    f_x = a3
    return z1, a1, z2, a2, z3, a3, f_x

# testing
print X_test.shape
testing_losses = []
for x,y in zip(X_test, y_test):

    x = scaler.transform(x)
    x = x.reshape(x.shape[0],1)
    y = y.reshape(y.shape[0],1)

    z1, a1, z2, a2, z3, a3, f_x = forward_prop(x, W[0], b[0], W[1], b[1], W[2], b[2])
    
    if y[0][0] == 0:
        print y[0],y[1]
        print f_x[0],f_x[1]
    
    testing_loss = np.round(loss(f_x,y),2)
    testing_losses.append(testing_loss)

plt.title('TESTING LOSSES')
plt.plot(testing_losses)
plt.legend(['Testing'])
plt.xlabel('Example')
plt.ylabel('Loss')
plt.show()
# Out:
# (501, 91)
# [0] [1]
# [ 0.97861972] [ 0.02138028]
# [0] [1]
# [ 0.97894002] [ 0.02105998]
# [0] [1]
# [ 0.98013191] [ 0.01986809]
# [0] [1]
# [ 0.97885609] [ 0.02114391]
# [0] [1]
# [ 0.97904289] [ 0.02095711]
# [0] [1]
# [ 0.9770833] [ 0.0229167]
# [0] [1]
# [ 0.97290902] [ 0.02709098]
# [0] [1]
# [ 0.97639366] [ 0.02360634]
# [0] [1]
# [ 0.97852445] [ 0.02147555]
# [0] [1]
# [ 0.97880549] [ 0.02119451]
# [0] [1]
# [ 0.97977366] [ 0.02022634]
# [0] [1]
# [ 0.97878403] [ 0.02121597]
# [0] [1]
# [ 0.97940626] [ 0.02059374]
# [0] [1]
# [ 0.97853557] [ 0.02146443]
# [0] [1]
# [ 0.97288595] [ 0.02711405]
# [0] [1]
# [ 0.97420629] [ 0.02579371]
# [0] [1]
# [ 0.97859033] [ 0.02140967]
# [0] [1]
# [ 0.9775918] [ 0.0224082]
# [0] [1]
# [ 0.97475506] [ 0.02524494]
# [0] [1]
# [ 0.9753114] [ 0.0246886]
# [0] [1]
# [ 0.97043796] [ 0.02956204]
# [0] [1]
# [ 0.97818851] [ 0.02181149]
# [0] [1]
# [ 0.96917921] [ 0.03082079]
# [0] [1]
# [ 0.97801027] [ 0.02198973]
# [0] [1]
# [ 0.97736535] [ 0.02263465]
# [0] [1]
# [ 0.97518059] [ 0.02481941]
# [0] [1]
# [ 0.97964882] [ 0.02035118]
# [0] [1]
# [ 0.97794148] [ 0.02205852]
# [0] [1]
# [ 0.98052682] [ 0.01947318]
# [0] [1]
# [ 0.97871223] [ 0.02128777]
# [0] [1]
# [ 0.97736231] [ 0.02263769]

# %% [markdown]
# ---

# %%
pred_df = GQ_prediction_df[GQ_prediction_df['label_x'].apply(np.isnan) == True]
pred_df = pred_df.drop(['label_x','label_y','date'], axis=1)
pred_df = pred_df.dropna()
pred_tickers = pred_df['ticker'].unique()
pred_df['ticker'] = pred_df['ticker'].astype('category').cat.codes
pred_X = pred_df.values
pred_X = skb.transform(pred_X)

# %%
for i in xrange(pred_X.shape[0]):
    x = scaler.transform(pred_X[i])
    x = x.reshape(x.shape[0],1)
    
    z1, a1, z2, a2, z3, a3, f_x = forward_prop(x, W[0], b[0], W[1], b[1], W[2], b[2])
    
    print str(i).rjust(2), str(pred_tickers[i]).rjust(4), f_x[0], f_x[1]
# Out:
#  0 ACOR [ 0.93958608] [ 0.06041392]
#  1 AERI [ 0.93457632] [ 0.06542368]
#  2 AFFX [ 0.94939971] [ 0.05060029]
#  3 AGEN [ 0.95841336] [ 0.04158664]
#  4 ARIA [ 0.94485445] [ 0.05514555]
#  5 ARNA [ 0.92620772] [ 0.07379228]
#  6 ARWR [ 0.94826391] [ 0.05173609]
#  7 AXDX [ 0.94479625] [ 0.05520375]
#  8 BABY [ 0.94283717] [ 0.05716283]
#  9 BCRX [ 0.95857419] [ 0.04142581]
# 10 BIIB [ 0.93889745] [ 0.06110255]
# 11 BLUE [ 0.93911075] [ 0.06088925]
# 12 BRKR [ 0.95108521] [ 0.04891479]
# 13 CBPO [ 0.93924874] [ 0.06075126]
# 14 CLDN [ 0.91604656] [ 0.08395344]
# 15 CLDX [ 0.95616091] [ 0.04383909]
# 16 CNMD [ 0.94353119] [ 0.05646881]
# 17 CPHD [ 0.942385] [ 0.057615]
# 18 CPRX [ 0.95276388] [ 0.04723612]
# 19 CRIS [ 0.94672236] [ 0.05327764]
# 20 CYBX [ 0.94088566] [ 0.05911434]
# 21 CYNO [ 0.9393136] [ 0.0606864]
# 22 CYTR [ 0.95957647] [ 0.04042353]
# 23 DSCO [ 0.94584207] [ 0.05415793]
# 24 DYAX [ 0.94283572] [ 0.05716428]
# 25 ECYT [ 0.95064776] [ 0.04935224]
# 26 ENZN [ 0.89026244] [ 0.10973756]
# 27 EXAS [ 0.95154374] [ 0.04845626]
# 28 EXEL [ 0.93502592] [ 0.06497408]
# 29 FATE [ 0.95030459] [ 0.04969541]
# 30 FEIC [ 0.94026503] [ 0.05973497]
# 31 FLDM [ 0.95474863] [ 0.04525137]
# 32 GILD [ 0.93909254] [ 0.06090746]
# 33 GNCA [ 0.9614374] [ 0.0385626]
# 34 HALO [ 0.9530845] [ 0.0469155]
# 35 IART [ 0.94231626] [ 0.05768374]
# 36 IDRA [ 0.95375042] [ 0.04624958]
# 37 IDXX [ 0.93957211] [ 0.06042789]
# 38 ILMN [ 0.9390253] [ 0.0609747]
# 39 IMMU [ 0.9544389] [ 0.0455611]
# 40 INCY [ 0.93918309] [ 0.06081691]
# 41  INO [ 0.97300945] [ 0.02699055]
# 42 LJPC [ 0.9475889] [ 0.0524111]
# 43 LPCN [ 0.97013303] [ 0.02986697]
# 44 MASI [ 0.9449955] [ 0.0550045]
# 45 MEIP [ 0.94601773] [ 0.05398227]
# 46 MNKD [ 0.94639125] [ 0.05360875]
# 47 MNTA [ 0.95826082] [ 0.04173918]
# 48 MYGN [ 0.94450452] [ 0.05549548]
# 49 NBIX [ 0.94216946] [ 0.05783054]
# 50 NEOG [ 0.94427246] [ 0.05572754]
# 51 NSTG [ 0.96942549] [ 0.03057451]
# 52 NVAX [ 0.96907251] [ 0.03092749]
# 53 NVDQ [ 0.96700072] [ 0.03299928]
# 54 NXTM [ 0.96780913] [ 0.03219087]
# 55 OGXI [ 0.88790985] [ 0.11209015]
# 56 ONTY [ 0.95293792] [ 0.04706208]
# 57 OREX [ 0.95934451] [ 0.04065549]
# 58 OSIR [ 0.95457226] [ 0.04542774]
# 59 PACB [ 0.96597] [ 0.03403]
# 60 PDLI [ 0.9484342] [ 0.0515658]
# 61 PGNX [ 0.98141514] [ 0.01858486]
# 62 PRXL [ 0.94150844] [ 0.05849156]
# 63 QDEL [ 0.95453499] [ 0.04546501]
# 64 QGEN [ 0.9512214] [ 0.0487786]
# 65 RGEN [ 0.9455943] [ 0.0544057]
# 66 RMTI [ 0.97904394] [ 0.02095606]
# 67 RPRX [ 0.97243942] [ 0.02756058]
# 68 SGEN [ 0.94506868] [ 0.05493132]
# 69 SGMO [ 0.97193368] [ 0.02806632]
# 70 SGYP [ 0.9721325] [ 0.0278675]
# 71 SNMX [ 0.97312192] [ 0.02687808]
# 72 SPNC [ 0.95577123] [ 0.04422877]
# 73 SRNE [ 0.98235012] [ 0.01764988]
# 74 STEM [ 0.94537447] [ 0.05462553]
# 75 TECH [ 0.93989852] [ 0.06010148]
# 76 THLD [ 0.95853932] [ 0.04146068]
# 77 THOR [ 0.94105907] [ 0.05894093]
# 78 TNXP [ 0.94994773] [ 0.05005227]
# 79 TROV [ 0.96790991] [ 0.03209009]
# 80 TRVN [ 0.97521951] [ 0.02478049]
# 81 XLRN [ 0.94781845] [ 0.05218155]
# 82 ZLTQ [ 0.94476542] [ 0.05523458]
